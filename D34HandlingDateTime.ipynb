# %%
import numpy as np
import pandas as pd

# %%
date=pd.read_csv('orders.csv')
time=pd.read_csv('messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
date.info()  ##date is in object which needs to be changed
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
#WORKING WITH DATES

# %%
#Convert to datetime datatype
date['date']=pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %%
## EXTRACT YEAR

# %%
date['date_year']=date['date'].dt.year
date.sample(5)
# Out:
#           date  product_id  city_id  orders  date_year
# 119 2019-08-15         650       25       2       2019
# 967 2019-06-11        6093       28       1       2019
# 96  2018-08-23         925       25       4       2018
# 156 2019-04-25         568        8      25       2019
# 854 2019-07-12        4030        0       2       2019

# %%
## EXTRACT MONTH

# %%
date['date_month_no']=date['date'].dt.month
date.sample(5)
date.drop(columns=['date_month'])
# Out:
#           date  date_year  date_month_no date_month_name  date_day  date_dow
# 0   2019-12-10       2019             12        December        10         1
# 1   2018-08-15       2018              8          August        15         2
# 2   2018-10-23       2018             10         October        23         1
# 3   2019-08-17       2019              8          August        17         5
# 4   2019-01-06       2019              1         January         6         6
# ..         ...        ...            ...             ...       ...       ...
# 995 2018-10-08       2018             10         October         8         0
# 996 2018-12-06       2018             12        December         6         3
# 997 2019-05-07       2019              5             May         7         1
# 998 2019-03-03       2019              3           March         3         6
# 999 2019-10-15       2019             10         October        15         1
#
# [1000 rows x 6 columns]

# %%
date.sample(5)
# Out:
#           date  date_year  date_month  date_month_no date_month_name  \
# 523 2019-06-18       2019           6              6            June
# 304 2018-09-15       2018           9              9       September
# 706 2019-01-04       2019           1              1         January
# 847 2019-08-17       2019           8              8          August
# 150 2019-07-10       2019           7              7            July
#
#      date_day  date_dow
# 523        18         1
# 304        15         5
# 706         4         4
# 847        17         5
# 150        10         2

# %%
date['date_month_name']=date['date'].dt.month_name()
date.sample(5)
# Out:
#           date  date_year  date_month  date_month_no date_month_name  \
# 533 2019-01-22       2019           1              1         January
# 935 2019-10-30       2019          10             10         October
# 193 2019-05-18       2019           5              5             May
# 722 2019-10-16       2019          10             10         October
# 13  2018-08-24       2018           8              8          August
#
#      date_day  date_dow
# 533        22         1
# 935        30         2
# 193        18         5
# 722        16         2
# 13         24         4

# %%
## Extract Day of month (tarik ta)

# %%
date['date_day']=date['date'].dt.day
date.sample(5)
# Out:
#           date  date_year  date_month  date_month_no date_month_name  \
# 659 2019-06-01       2019           6              6            June
# 81  2019-03-22       2019           3              3           March
# 517 2019-01-06       2019           1              1         January
# 645 2019-02-11       2019           2              2        February
# 765 2018-11-01       2018          11             11        November
#
#      date_day  date_dow
# 659         1         5
# 81         22         4
# 517         6         6
# 645        11         0
# 765         1         3

# %%
#DAY OF WEEK 
date['date_dow']=date['date'].dt.dayofweek
date.sample(5)
# Out:
#           date  date_year  date_month  date_month_no date_month_name  \
# 522 2019-10-30       2019          10             10         October
# 817 2019-10-20       2019          10             10         October
# 126 2019-07-20       2019           7              7            July
# 245 2019-07-28       2019           7              7            July
# 608 2019-04-10       2019           4              4           April
#
#      date_day  date_dow
# 522        30         2
# 817        20         6
# 126        20         5
# 245        28         6
# 608        10         2

# %%
## DAY OF WEEK NAME
date['date_dow_name']=date['date'].dt.day_name()
date.sample(5)
# Out:
#           date  date_year  date_month  date_month_no date_month_name  \
# 214 2019-06-30       2019           6              6            June
# 94  2019-04-10       2019           4              4           April
# 41  2019-04-07       2019           4              4           April
# 220 2019-12-14       2019          12             12        December
# 726 2019-10-20       2019          10             10         October
#
#      date_day  date_dow date_dow_name
# 214        30         6        Sunday
# 94         10         2     Wednesday
# 41          7         6        Sunday
# 220        14         5      Saturday
# 726        20         6        Sunday

# %%
#is weekend??
date['is_weekend?']=np.where(date['date_dow_name'].isin(['Sunday','Saturday']),1,0)

# %%
date.sample(5)
# Out:
#           date  date_year  date_month  date_month_no date_month_name  \
# 513 2019-10-30       2019          10             10         October
# 356 2018-09-13       2018           9              9       September
# 44  2018-08-03       2018           8              8          August
# 647 2018-09-05       2018           9              9       September
# 841 2019-11-17       2019          11             11        November
#
#      date_day  date_dow date_dow_name  is_weekend?
# 513        30         2     Wednesday            0
# 356        13         3      Thursday            0
# 44          3         4        Friday            0
# 647         5         2     Wednesday            0
# 841        17         6        Sunday            1

# %%
##Extract week of the year
date['date_week']=date['date'].dt.week
date.sample(5)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2920\3086468889.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   date['date_week']=date['date'].dt.week
#           date  date_year  date_month  date_month_no date_month_name  \
# 157 2019-02-18       2019           2              2        February
# 264 2019-04-26       2019           4              4           April
# 806 2019-07-13       2019           7              7            July
# 493 2019-06-04       2019           6              6            June
# 120 2018-11-19       2018          11             11        November
#
#      date_day  date_dow date_dow_name  is_weekend?  date_week
# 157        18         0        Monday            0          8
# 264        26         4        Friday            0         17
# 806        13         5      Saturday            1         28
# 493         4         1       Tuesday            0         23
# 120        19         0        Monday            0         47

# %%
#EXTRACT QUARTER
date['quarter']=date['date'].dt.quarter
date.sample(5)
# Out:
#           date  date_year  date_month  date_month_no date_month_name  \
# 666 2019-03-19       2019           3              3           March
# 996 2018-12-06       2018          12             12        December
# 465 2018-09-13       2018           9              9       September
# 889 2019-07-20       2019           7              7            July
# 499 2018-09-28       2018           9              9       September
#
#      date_day  date_dow date_dow_name  is_weekend?  date_week  quarter
# 666        19         1       Tuesday            0         12        1
# 996         6         3      Thursday            0         49        4
# 465        13         3      Thursday            0         37        3
# 889        20         5      Saturday            1         29        3
# 499        28         4        Friday            0         39        3

# %%
#EXTRACT SEMESTER
date['semester']=np.where(date['quarter'].isin([1,2]),1,2)
date.sample(5)
# Out:
#           date  date_year  date_month  date_month_no date_month_name  \
# 964 2018-12-06       2018          12             12        December
# 410 2019-05-17       2019           5              5             May
# 340 2019-11-02       2019          11             11        November
# 620 2019-03-21       2019           3              3           March
# 349 2018-09-02       2018           9              9       September
#
#      date_day  date_dow date_dow_name  is_weekend?  date_week  quarter  \
# 964         6         3      Thursday            0         49        4
# 410        17         4        Friday            0         20        2
# 340         2         5      Saturday            1         44        4
# 620        21         3      Thursday            0         12        1
# 349         2         6        Sunday            1         35        3
#
#      semester
# 964         2
# 410         1
# 340         2
# 620         1
# 349         2

# %%
##EXTRACT TIME ELAPSED BETWEEN DATES
import datetime
today=datetime.datetime.today()
today
# Out:
# datetime.datetime(2024, 2, 17, 13, 5, 23, 395868)

# %%
today-date['date']
# Out:
# 0     1530 days 13:05:23.395868
# 1     2012 days 13:05:23.395868
# 2     1943 days 13:05:23.395868
# 3     1645 days 13:05:23.395868
# 4     1868 days 13:05:23.395868
#                  ...
# 995   1958 days 13:05:23.395868
# 996   1899 days 13:05:23.395868
# 997   1747 days 13:05:23.395868
# 998   1812 days 13:05:23.395868
# 999   1586 days 13:05:23.395868
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today-date['date']).dt.days
# Out:
# 0      1530
# 1      2012
# 2      1943
# 3      1645
# 4      1868
#        ...
# 995    1958
# 996    1899
# 997    1747
# 998    1812
# 999    1586
# Name: date, Length: 1000, dtype: int64

# %%
# Months passed

np.round((today -date['date']) / np.timedelta64(1, 'M'),0)
# Out:
# 0      50.0
# 1      66.0
# 2      64.0
# 3      54.0
# 4      61.0
#        ...
# 995    64.0
# 996    62.0
# 997    57.0
# 998    60.0
# 999    52.0
# Name: date, Length: 1000, dtype: float64

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
time['date']=pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %%
time['hour']=time['date'].dt.hour
time['min']=time['date'].dt.minute
time['sec']=time['date'].dt.second
time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec
# 0     0   50    0
# 1    23   40    0
# 2     0   21    0
# 3     0   31    0
# 4    23   11    0

# %%
##EXTRACT TIME PART
time['time']=time['date'].dt.time
time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec      time
# 0     0   50    0  00:50:00
# 1    23   40    0  23:40:00
# 2     0   21    0  00:21:00
# 3     0   31    0  00:31:00
# 4    23   11    0  23:11:00

# %%
today-time['date']
# Out:
# 0     3716 days 12:15:23.395868
# 1     3580 days 13:25:23.395868
# 2     4066 days 12:44:23.395868
# 3     3368 days 12:34:23.395868
# 4     3765 days 13:54:23.395868
#                  ...
# 995   4355 days 12:15:23.395868
# 996   3676 days 13:51:23.395868
# 997   4141 days 13:28:23.395868
# 998   4257 days 13:31:23.395868
# 999   3529 days 13:40:23.395868
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
# in seconds

(today - time['date'])/np.timedelta64(1,'s')
# Out:
# 0      3.211065e+08
# 1      3.093603e+08
# 2      3.513483e+08
# 3      2.910405e+08
# 4      3.253461e+08
#            ...
# 995    3.763161e+08
# 996    3.176563e+08
# 997    3.578309e+08
# 998    3.678535e+08
# 999    3.049548e+08
# Name: date, Length: 1000, dtype: float64

# %%
# in minutes

(today - time['date'])/np.timedelta64(1,'m')
# Out:
# 0      5.351775e+06
# 1      5.156005e+06
# 2      5.855804e+06
# 3      4.850674e+06
# 4      5.422434e+06
#            ...
# 995    6.271935e+06
# 996    5.294271e+06
# 997    5.963848e+06
# 998    6.130891e+06
# 999    5.082580e+06
# Name: date, Length: 1000, dtype: float64
